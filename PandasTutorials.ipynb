# %% [markdown]
# <a href="https://colab.research.google.com/github/keshavvprabhu/RobotFramework_ETL/blob/main/PandasTutorials.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name', 'Type 1']]
# Out:
#                       Name   Type 1
# 0                Bulbasaur    Grass
# 1                  Ivysaur    Grass
# 2                 Venusaur    Grass
# 3    VenusaurMega Venusaur    Grass
# 4               Charmander     Fire
# ..                     ...      ...
# 795                Diancie     Rock
# 796    DiancieMega Diancie     Rock
# 797    HoopaHoopa Confined  Psychic
# 798     HoopaHoopa Unbound  Psychic
# 799              Volcanion     Fire
#
# [800 rows x 2 columns]

# %%
df.iloc[0:5]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.loc[df['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
sample_df = df[['Name', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']].sample(5).sort_values(by=['Name'])
sample_df
# Out:
#          Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 391  Chimecho  65      50       70       95       80     65
# 508   Mantyke  45      20       50       60      120     50
# 48     Oddish  45      50       55       75       65     30
# 743   Pangoro  95     124       78       69       71     58
# 575  Simipour  75      98       63       98       63    101

# %%
sample_df.sort_values(by='Name').plot(kind='barh')

# %%
sample_df.style.background_gradient(cmap='RdYlBu').hide_index()
# Out:
# <style type="text/css">
# #T_ad7b3_row0_col1 {
#   background-color: #fee090;
#   color: #000000;
# }
# #T_ad7b3_row0_col2, #T_ad7b3_row2_col2 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_ad7b3_row0_col3 {
#   background-color: #a3d3e6;
#   color: #000000;
# }
# #T_ad7b3_row0_col4 {
#   background-color: #4167ad;
#   color: #f1f1f1;
# }
# #T_ad7b3_row0_col5 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_ad7b3_row0_col6 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_ad7b3_row1_col1, #T_ad7b3_row1_col2, #T_ad7b3_row1_col3, #T_ad7b3_row1_col4, #T_ad7b3_row2_col1, #T_ad7b3_row2_col6, #T_ad7b3_row4_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ad7b3_row1_col5, #T_ad7b3_row3_col1, #T_ad7b3_row3_col2, #T_ad7b3_row3_col3, #T_ad7b3_row4_col4, #T_ad7b3_row4_col6 {
#   background-color: #313695;
#   color: #f1f1f1;
# }
# #T_ad7b3_row1_col6 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_ad7b3_row2_col3 {
# ...

# %%
for index, row in df.iterrows():
    if index < 2:
        print(row)
        print('-' * 20)
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# --------------------
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# --------------------

# %%
df.sort_values(['Attack', 'HP'], ascending=[1,1]).head()
# Out:
#        #      Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 488  440   Happiny  Normal    NaN  100       5        5       15       65
# 121  113   Chansey  Normal    NaN  250       5        5       35      105
# 139  129  Magikarp   Water    NaN   20      10       55       15       20
# 230  213   Shuckle     Bug   Rock   20      10      230       10      230
# 261  242   Blissey  Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# 488     30           4      False
# 121     50           1      False
# 139     80           1      False
# 230      5           2      False
# 261     55           2      False

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
df.sort_values('Total', ascending=False).loc[df['Name'] == 'Pikachu']
# Out:
#      #     Name    Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 30  25  Pikachu  Electric    NaN  35      55       40       50       50
#
#     Speed  Generation  Legendary  Total
# 30     90           1      False    320

# %%
df_type1_mean = df.groupby(['Type 1', 'Type 2']).mean()
df_type1_mean
# Out:
#                           #         HP      Attack     Defense     Sp. Atk  \
# Type 1 Type 2
# Bug    Electric  595.500000  60.000000   62.000000   55.000000   77.000000
#        Fighting  214.000000  80.000000  155.000000   95.000000   40.000000
#        Fire      636.500000  70.000000   72.500000   60.000000   92.500000
#        Flying    286.285714  63.000000   70.142857   61.571429   72.857143
#        Ghost     292.000000   1.000000   90.000000   45.000000   30.000000
# ...                     ...        ...         ...         ...         ...
# Water  Ice       103.000000  90.000000   83.333333  113.333333   80.000000
#        Poison    118.666667  61.666667   68.333333   58.333333   61.666667
#        Psychic   111.800000  87.000000   73.000000  104.000000   94.000000
#        Rock      430.000000  70.750000   82.750000  112.750000   61.500000
#        Steel     395.000000  84.000000   86.000000   88.000000  111.000000
#
# ...
